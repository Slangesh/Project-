# %%
name="langeshwari"
age=25
CGPA=8.5
placed=False
print("Student Name:",name)
print("Age:",age)
print("CGAP:",CGPA)
print("placed:",placed)
print(type(name))
print(type(age))
print(type(CGPA))
print(type(placed))
# Out:
# Student Name: langeshwari
# Age: 25
# CGAP: 8.5
# placed: False
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
name="langeshwari"
print(len(name))
# Out:
# 11

# %%
name=["Sakthi","Meena","Maha"]
name.append("flora")
marks=[50,48,80]
print(name)
print(marks[2])
print(len(name))
print(len(marks))
# Out:
# ['Sakthi', 'Meena', 'Maha', 'flora']
# 80
# 4
# 3

# %%
days=("Monday","Tuesday","Wedensday")
print(days[1])
# Out:
# Tuesday

# %%
student={
      "name":"langeshwari",
      "age":20
}
print(student)
# Out:
# {'name': 'langeshwari', 'age': 20}

# %%
import numpy as np
marks=np.array([80,48,30,90])
print(marks)
# Out:
# [80 48 30 90]

# %%
import numpy as np
a=np.array([1,2,3])
b=np.array([5,6,7])
print(a+b)
# Out:
# [ 6  8 10]
